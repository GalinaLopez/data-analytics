# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns   

df = pd.read_csv("C:\Users\End-User\Desktop\Fergal\Telco-Customer-Churn.csv") #Reading the dataset in a dataframe using Pandas

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['tenure'].hist(bins=50)

# %%
temp1 = df['Dependents'].value_counts(ascending=True)
print temp1
#temp1 = temp1 / len(df) 
#print temp1
# Out:
# Yes    2110
# No     4933
# Name: Dependents, dtype: int64

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Dependents')
ax1.set_ylabel('Count of Customers')
ax1.set_title("Count of Customers by Dependents")
temp1.plot(kind='bar')

# %%
temp3 = pd.crosstab(df['Dependents'], df['Churn'])
#temp3 = temp3 / len(df)
print temp3
# normalizing dataframe by rows
temp3 = temp3.div(temp3.sum(axis=1), axis=0)
print temp3

# normalizing dataframe by columns
#temp3 = temp3.apply(lambda x: (x / sum(x)))

# normalizing dataframe by columns another way
#def f(s):
#    return s/sum(s)
#temp3 = temp3.apply(f, axis=0)

#fig = plt.figure(figsize=(10,8))
#ax3 = fig.add_subplot(122)

ax3 = temp3.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)
ax3.set_xlabel('Dependents')
ax3.set_ylabel('Churn percentage')
ax3.set_title("Churn percentage by dependents")

#temp3.plot(kind='bar', stacked=False, color=['red','blue'], grid=False)
# Out:
# Churn         No   Yes
# Dependents
# No          3390  1543
# Yes         1784   326
# Churn             No       Yes
# Dependents
# No          0.687209  0.312791
# Yes         0.845498  0.154502
